# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import autokeras as ak
from sklearn.model_selection import train_test_split
import jinja2
from pycaret.classification import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\jongm\Desktop\MINI\project\mimiciv-High-blood-pressure\modeling\automl.ipynb Cell 1' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/MINI/project/mimiciv-High-blood-pressure/modeling/automl.ipynb#ch0000000?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/MINI/project/mimiciv-High-blood-pressure/modeling/automl.ipynb#ch0000000?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/MINI/project/mimiciv-High-blood-pressure/modeling/automl.ipynb#ch0000000?line=2'>3</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/MINI/project/mimiciv-High-blood-pressure/modeling/automl.ipynb#ch0000000?line=3'>4</a> import autokeras as ak
#       <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/MINI/project/mimiciv-High-blood-pressure/modeling/automl.ipynb#ch0000000?line=4'>5</a> from sklearn.model_selection import train_test_split
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\tensorflow\__init__.py:41, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/__init__.py?line=37'>38</a> import six as _six
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/__init__.py?line=38'>39</a> import sys as _sys
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/__init__.py?line=40'>41</a> from tensorflow.python.tools import module_util as _module_util
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/__init__.py?line=41'>42</a> from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/__init__.py?line=43'>44</a> # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\tensorflow\python\__init__.py:47, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/__init__.py?line=44'>45</a> from tensorflow.python import data
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/__init__.py?line=45'>46</a> from tensorflow.python import distribute
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/__init__.py?line=46'>47</a> from tensorflow.python import keras
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/__init__.py?line=47'>48</a> from tensorflow.python.feature_column import feature_column_lib as feature_column
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/__init__.py?line=48'>49</a> from tensorflow.python.layers import layers
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\tensorflow\python\keras\__init__.py:27, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/__init__.py?line=23'>24</a> from tensorflow.python import tf2
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/__init__.py?line=25'>26</a> # See b/110718070#comment18 for more details about this import.
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/__init__.py?line=26'>27</a> from tensorflow.python.keras import models
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/__init__.py?line=28'>29</a> from tensorflow.python.keras.engine.input_layer import Input
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/__init__.py?line=29'>30</a> from tensorflow.python.keras.engine.sequential import Sequential
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\tensorflow\python\keras\models.py:26, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/models.py?line=23'>24</a> from tensorflow.python.keras import metrics as metrics_module
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/models.py?line=24'>25</a> from tensorflow.python.keras import optimizers
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/models.py?line=25'>26</a> from tensorflow.python.keras.engine import functional
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/models.py?line=26'>27</a> from tensorflow.python.keras.engine import sequential
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/models.py?line=27'>28</a> from tensorflow.python.keras.engine import training
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\tensorflow\python\keras\engine\functional.py:38, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=35'>36</a> from tensorflow.python.keras.engine import keras_tensor
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=36'>37</a> from tensorflow.python.keras.engine import node as node_module
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=37'>38</a> from tensorflow.python.keras.engine import training as training_lib
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=38'>39</a> from tensorflow.python.keras.engine import training_utils
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/functional.py?line=39'>40</a> from tensorflow.python.keras.saving.saved_model import network_serialization
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\tensorflow\python\keras\engine\training.py:53, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/training.py?line=50'>51</a> from tensorflow.python.keras.engine import training_utils
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/training.py?line=51'>52</a> from tensorflow.python.keras.mixed_precision.experimental import loss_scale_optimizer as lso
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/training.py?line=52'>53</a> from tensorflow.python.keras.saving import hdf5_format
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/training.py?line=53'>54</a> from tensorflow.python.keras.saving import save
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/engine/training.py?line=54'>55</a> from tensorflow.python.keras.saving.saved_model import model_serialization
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py:41, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/saving/hdf5_format.py?line=38'>39</a> # pylint: disable=g-import-not-at-top
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/saving/hdf5_format.py?line=39'>40</a> try:
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/saving/hdf5_format.py?line=40'>41</a>   import h5py
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/saving/hdf5_format.py?line=41'>42</a>   HDF5_OBJECT_HEADER_LIMIT = 64512
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/tensorflow/python/keras/saving/hdf5_format.py?line=42'>43</a> except ImportError:
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\h5py\__init__.py:34, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=30'>31</a>     else:
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=31'>32</a>         raise
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=33'>34</a> from . import version
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=35'>36</a> if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=36'>37</a>     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=37'>38</a>            "this may cause problems").format(
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=38'>39</a>             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=39'>40</a>             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/__init__.py?line=40'>41</a>     ))
#
# File c:\Users\jongm\anaconda3\envs\tfkeras\lib\site-packages\h5py\version.py:17, in <module>
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/version.py?line=13'>14</a> from __future__ import absolute_import
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/version.py?line=15'>16</a> from collections import namedtuple
# ---> <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/version.py?line=16'>17</a> from . import h5 as _h5
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/version.py?line=17'>18</a> import sys
#      <a href='file:///c%3A/Users/jongm/anaconda3/envs/tfkeras/lib/site-packages/h5py/version.py?line=18'>19</a> import numpy
#
# File h5py\h5.pyx:41, in init h5py.h5()
#
# AttributeError: type object 'h5py.h5.H5PYConfig' has no attribute '__reduce_cython__'

# %%
df = pd.read_csv('../dataset/master_3.csv')
# df.head()

# %%
# drop_df = df.drop(['outcome_critical'], axis=1)
# x_train, x_test, y_train, y_test = train_test_split(drop_df, df['outcome_critical'], test_size=0.5, shuffle=True, random_state=2022)

# %%
drop_df = df.drop(list(df.filter(regex='cci_').columns), axis=1)

# %%
corr = df.corr(method='pearson')['outcome_critical']
corr.sort_values(ascending=False)
# Out:
# outcome_critical                1.000000
# outcome_icu_transfer_12h        0.971288
# outcome_inhospital_mortality    0.385000
# outcome_hospitalization         0.277768
# n_med                           0.202126
# ed_resprate_last                0.200978
# ed_heartrate_last               0.157348
# age                             0.153257
# triage_resprate                 0.131355
# n_icu_365d                      0.124064
# n_icu_90d                       0.113711
# cci_CHF                         0.085129
# eci_CHF                         0.085114
# n_icu_30d                       0.084543
# eci_FluidsLytes                 0.076142
# triage_heartrate                0.075372
# eci_Arrhythmia                  0.073491
# eci_HTN1                        0.068138
# eci_Coagulopathy                0.064700
# cci_Renal                       0.064045
# eci_Renal                       0.063832
# ed_temperature_last             0.060720
# eci_PHTN                        0.056837
# cci_PVD                         0.053254
# eci_PVD                         0.052945
# eci_Valvular                    0.052359
# cci_MI                          0.051238
# cci_Cancer1                     0.048566
# cci_Stroke                      0.048404
# eci_WeightLoss                  0.047341
# eci_DM1                         0.046708
# eci_Tumor2                      0.045592
# cci_Cancer2                     0.045592
# eci_Tumor1                      0.044207
# gender                          0.044115
# cci_DM1                         0.043618
# cci_DM2                         0.043366
# n_medrecon                      0.042495
# eci_NeuroOther                  0.042226
# cci_Pulmonary                   0.038654
# eci_Pulmonary                   0.038654
# eci_DM2                         0.038464
# eci_Paralysis                   0.034210
# eci_HTN2                        0.033466
# cci_Liver2                      0.033194
# cci_Dementia                    0.030889
# cci_Paralysis                   0.030707
# eci_Hypothyroid                 0.029613
# eci_Liver                       0.029410
# eci_Anemia                      0.028604
# cci_Liver1                      0.026348
# cci_PUD                         0.025508
# eci_BloodLoss                   0.025129
# n_hosp_90d                      0.024536
# chiefcom_shortness_of_breath    0.022926
# ed_los_hours                    0.022231
# chiefcom_fever_chills           0.020883
# n_hosp_30d                      0.016885
# eci_PUD                         0.016649
# triage_temperature              0.015228
# n_hosp_365d                     0.014875
# eci_Rheumatic                   0.014820
# eci_Lymphoma                    0.014489
# before_ed_mortality             0.014414
# eci_Obesity                     0.013383
# cci_Rheumatic                   0.012624
# eci_Depression                  0.004294
# ed_death                        0.003693
# eci_Alcohol                     0.001878
# stay_id                        -0.000161
# eci_HIV                        -0.000318
# cci_HIV                        -0.000318
# subject_id                     -0.000352
# index                          -0.001841
# in_year                        -0.008679
# eci_Psychoses                  -0.009586
# chiefcom_syncope               -0.011911
# chiefcom_cough                 -0.012764
# chiefcom_nausea_vomiting       -0.014013
# eci_Drugs                      -0.014547
# n_ed_90d                       -0.015690
# n_ed_30d                       -0.018871
# chiefcom_dizziness             -0.020681
# n_ed_365d                      -0.021021
# chiefcom_headache              -0.022497
# chiefcom_chest_pain            -0.032221
# chiefcom_back_pain             -0.040649
# outcome_ed_revisit_3d          -0.042888
# ed_o2sat_last                  -0.043064
# chiefcom_abdominal_pain        -0.046545
# ed_pain_last                   -0.061302
# triage_sbp                     -0.062784
# triage_dbp                     -0.064094
# ed_sbp_last                    -0.065252
# triage_pain                    -0.071413
# triage_o2sat                   -0.100144
# ed_dbp_last                    -0.103318
# triage_acuity                  -0.266756
# Name: outcome_critical, dtype: float64

# %%
drop_df = drop_df.drop(['outcome_icu_transfer_12h'], axis=1)

# %%
drop_df = drop_df.drop(['chiefcom_chest_pain', 'chiefcom_abdominal_pain',
    'chiefcom_headache', 'chiefcom_shortness_of_breath',
    'chiefcom_back_pain', 'chiefcom_cough', 'chiefcom_nausea_vomiting',
    'chiefcom_fever_chills', 'chiefcom_syncope', 'chiefcom_dizziness',
    'eci_CHF', 'eci_Arrhythmia', 'eci_Valvular', 'eci_PHTN', 'eci_PVD',
    'eci_HTN1', 'eci_HTN2', 'eci_Paralysis', 'eci_NeuroOther',
    'eci_Pulmonary', 'eci_DM1', 'eci_DM2', 'eci_Hypothyroid', 'eci_Renal',
    'eci_Liver', 'eci_PUD', 'eci_HIV', 'eci_Lymphoma', 'eci_Tumor2',
    'eci_Tumor1', 'eci_Rheumatic', 'eci_Coagulopathy', 'eci_Obesity',
    'eci_WeightLoss', 'eci_FluidsLytes', 'eci_BloodLoss', 'eci_Anemia',
    'eci_Alcohol', 'eci_Drugs', 'eci_Psychoses', 'eci_Depression'], axis=1)

# %%
drop_df.columns
# Out:
# Index(['index', 'subject_id', 'stay_id', 'intime', 'outtime', 'gender',
#        'in_year', 'age', 'outcome_inhospital_mortality', 'ed_death',
#        'before_ed_mortality', 'ed_los', 'outcome_hospitalization',
#        'outcome_critical', 'n_ed_30d', 'n_ed_90d', 'n_ed_365d',
#        'outcome_ed_revisit_3d', 'n_hosp_30d', 'n_hosp_90d', 'n_hosp_365d',
#        'n_icu_30d', 'n_icu_90d', 'n_icu_365d', 'ed_los_hours',
#        'triage_temperature', 'triage_heartrate', 'triage_resprate',
#        'triage_o2sat', 'triage_sbp', 'triage_dbp', 'triage_pain',
#        'triage_acuity', 'ed_temperature_last', 'ed_heartrate_last',
#        'ed_resprate_last', 'ed_o2sat_last', 'ed_sbp_last', 'ed_dbp_last',
#        'ed_pain_last', 'n_med', 'n_medrecon'],
#       dtype='object')

# %%
cflf = setup(data = drop_df, target='outcome_critical')
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            18:34:29
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                                 Data Type
# index                           ID Column
# subject_id                        Numeric
# stay_id                           Numeric
# intime                               Date
# outtime                              Date
# gender                        Categorical
# in_year                           Numeric
# age                               Numeric
# outcome_inhospital_mortality  Categorical
# ed_death                      Categorical
# before_ed_mortality           Categorical
# ed_los                        Categorical
# outcome_hospitalization       Categorical
# n_ed_30d                      Categorical
# n_ed_90d                          Numeric
# n_ed_365d                         Numeric
# outcome_ed_revisit_3d         Categorical
# n_hosp_30d                    Categorical
# n_hosp_90d                        Numeric
# n_hosp_365d                       Numeric
# n_icu_30d                     Categorical
# n_icu_90d                     Categorical
# n_icu_365d                    Categorical
# ed_los_hours                      Numeric
# triage_temperature                Numeric
# triage_heartrate                  Numeric
# triage_resprate                   Numeric
# triage_o2sat                      Numeric
# triage_sbp                        Numeric
# triage_dbp                        Numeric
# triage_pain                       Numeric
# triage_acuity                     Numeric
# ed_temperature_last               Numeric
# ed_heartrate_last                 Numeric
# ed_resprate_last                  Numeric
# ed_o2sat_last                     Numeric
# ed_sbp_last                       Numeric
# ed_dbp_last                       Numeric
# ed_pain_last                      Numeric
# n_med                             Numeric
# n_medrecon                        Numeric
# outcome_critical                    Label
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\jongm\Desktop\mini\projects\mimiciv-High-blood-pressure\modeling\automl.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/mini/projects/mimiciv-High-blood-pressure/modeling/automl.ipynb#ch0000004?line=0'>1</a> clf = setup(data = drop_df, target='outcome_critical')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pycaret\classification.py:599, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=595'>596</a> if log_plots == True:
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=596'>597</a>     log_plots = ["auc", "confusion_matrix", "feature"]
# --> <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=598'>599</a> return pycaret.internal.tabular.setup(
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=599'>600</a>     ml_usecase="classification",
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=600'>601</a>     available_plots=available_plots,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=601'>602</a>     data=data,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=602'>603</a>     target=target,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=603'>604</a>     train_size=train_size,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=604'>605</a>     test_data=test_data,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=605'>606</a>     preprocess=preprocess,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=606'>607</a>     imputation_type=imputation_type,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=607'>608</a>     iterative_imputation_iters=iterative_imputation_iters,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=608'>609</a>     categorical_features=categorical_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=609'>610</a>     categorical_imputation=categorical_imputation,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=610'>611</a>     categorical_iterative_imputer=categorical_iterative_imputer,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=611'>612</a>     ordinal_features=ordinal_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=612'>613</a>     high_cardinality_features=high_cardinality_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=613'>614</a>     high_cardinality_method=high_cardinality_method,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=614'>615</a>     numeric_features=numeric_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=615'>616</a>     numeric_imputation=numeric_imputation,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=616'>617</a>     numeric_iterative_imputer=numeric_iterative_imputer,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=617'>618</a>     date_features=date_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=618'>619</a>     ignore_features=ignore_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=619'>620</a>     normalize=normalize,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=620'>621</a>     normalize_method=normalize_method,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=621'>622</a>     transformation=transformation,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=622'>623</a>     transformation_method=transformation_method,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=623'>624</a>     handle_unknown_categorical=handle_unknown_categorical,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=624'>625</a>     unknown_categorical_method=unknown_categorical_method,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=625'>626</a>     pca=pca,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=626'>627</a>     pca_method=pca_method,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=627'>628</a>     pca_components=pca_components,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=628'>629</a>     ignore_low_variance=ignore_low_variance,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=629'>630</a>     combine_rare_levels=combine_rare_levels,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=630'>631</a>     rare_level_threshold=rare_level_threshold,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=631'>632</a>     bin_numeric_features=bin_numeric_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=632'>633</a>     remove_outliers=remove_outliers,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=633'>634</a>     outliers_threshold=outliers_threshold,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=634'>635</a>     remove_multicollinearity=remove_multicollinearity,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=635'>636</a>     multicollinearity_threshold=multicollinearity_threshold,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=636'>637</a>     remove_perfect_collinearity=remove_perfect_collinearity,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=637'>638</a>     create_clusters=create_clusters,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=638'>639</a>     cluster_iter=cluster_iter,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=639'>640</a>     polynomial_features=polynomial_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=640'>641</a>     polynomial_degree=polynomial_degree,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=641'>642</a>     trigonometry_features=trigonometry_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=642'>643</a>     polynomial_threshold=polynomial_threshold,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=643'>644</a>     group_features=group_features,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=644'>645</a>     group_names=group_names,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=645'>646</a>     feature_selection=feature_selection,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=646'>647</a>     feature_selection_threshold=feature_selection_threshold,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=647'>648</a>     feature_selection_method=feature_selection_method,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=648'>649</a>     feature_interaction=feature_interaction,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=649'>650</a>     feature_ratio=feature_ratio,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=650'>651</a>     interaction_threshold=interaction_threshold,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=651'>652</a>     fix_imbalance=fix_imbalance,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=652'>653</a>     fix_imbalance_method=fix_imbalance_method,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=653'>654</a>     data_split_shuffle=data_split_shuffle,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=654'>655</a>     data_split_stratify=data_split_stratify,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=655'>656</a>     fold_strategy=fold_strategy,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=656'>657</a>     fold=fold,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=657'>658</a>     fold_shuffle=fold_shuffle,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=658'>659</a>     fold_groups=fold_groups,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=659'>660</a>     n_jobs=n_jobs,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=660'>661</a>     use_gpu=use_gpu,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=661'>662</a>     custom_pipeline=custom_pipeline,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=662'>663</a>     html=html,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=663'>664</a>     session_id=session_id,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=664'>665</a>     log_experiment=log_experiment,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=665'>666</a>     experiment_name=experiment_name,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=666'>667</a>     experiment_custom_tags=experiment_custom_tags,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=667'>668</a>     log_plots=log_plots,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=668'>669</a>     log_profile=log_profile,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=669'>670</a>     log_data=log_data,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=670'>671</a>     silent=silent,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=671'>672</a>     verbose=verbose,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=672'>673</a>     profile=profile,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=673'>674</a>     profile_kwargs=profile_kwargs,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/classification.py?line=674'>675</a> )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pycaret\internal\tabular.py:1408, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/tabular.py?line=1404'>1405</a>     train_data = pd.concat([X_train, y_train], axis=1)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/tabular.py?line=1405'>1406</a>     test_data = pd.concat([X_test, y_test], axis=1)
# -> <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/tabular.py?line=1407'>1408</a> train_data = prep_pipe.fit_transform(train_data)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/tabular.py?line=1408'>1409</a> # workaround to also transform target
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/tabular.py?line=1409'>1410</a> dtypes.final_training_columns.append(target)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\pipeline.py:367, in Pipeline.fit_transform(self, X, y, **fit_params)
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=339'>340</a> """Fit the model and transform with the final estimator
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=340'>341</a>
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=341'>342</a> Fits all the transforms one after the other and transforms the
#    (...)
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=363'>364</a>     Transformed samples
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=364'>365</a> """
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=365'>366</a> fit_params_steps = self._check_fit_params(**fit_params)
# --> <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=366'>367</a> Xt = self._fit(X, y, **fit_params_steps)
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=368'>369</a> last_step = self._final_estimator
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=369'>370</a> with _print_elapsed_time('Pipeline',
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=370'>371</a>                          self._log_message(len(self.steps) - 1)):
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\pipeline.py:292, in Pipeline._fit(self, X, y, **fit_params_steps)
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=289'>290</a>     cloned_transformer = clone(transformer)
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=290'>291</a> # Fit or load from cache the current transformer
# --> <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=291'>292</a> X, fitted_transformer = fit_transform_one_cached(
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=292'>293</a>     cloned_transformer, X, y, None,
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=293'>294</a>     message_clsname='Pipeline',
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=294'>295</a>     message=self._log_message(step_idx),
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=295'>296</a>     **fit_params_steps[name])
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=296'>297</a> # Replace the transformer of the step with the fitted
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=297'>298</a> # transformer. This is necessary when loading the transformer
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=298'>299</a> # from the cache.
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=299'>300</a> self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\jongm\AppData\Local\Programs\Python\Python38\lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     <a href='file:///c%3A/Users/jongm/AppData/Local/Programs/Python/Python38/lib/site-packages/joblib/memory.py?line=347'>348</a> def __call__(self, *args, **kwargs):
# --> <a href='file:///c%3A/Users/jongm/AppData/Local/Programs/Python/Python38/lib/site-packages/joblib/memory.py?line=348'>349</a>     return self.func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\pipeline.py:740, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=737'>738</a> with _print_elapsed_time(message_clsname, message):
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=738'>739</a>     if hasattr(transformer, 'fit_transform'):
# --> <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=739'>740</a>         res = transformer.fit_transform(X, y, **fit_params)
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=740'>741</a>     else:
#     <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/sklearn/pipeline.py?line=741'>742</a>         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pycaret\internal\preprocess.py:1624, in Dummify.fit_transform(self, dataset, y)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1621'>1622</a> self.fit(data)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1622'>1623</a> # fit without target and only categorical columns
# -> <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1623'>1624</a> array = self.ohe.transform(
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1624'>1625</a>     data.drop(self.target, axis=1, errors="ignore").select_dtypes(
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1625'>1626</a>         include=("object")
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1626'>1627</a>     )
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1627'>1628</a> ).toarray()
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1628'>1629</a> data_dummies = pd.DataFrame(array, columns=self.data_columns)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/pycaret/internal/preprocess.py?line=1629'>1630</a> data_dummies.index = self.data_nonc.index
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\sparse\compressed.py:1029, in _cs_matrix.toarray(self, order, out)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/scipy/sparse/compressed.py?line=1026'>1027</a> if out is None and order is None:
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/scipy/sparse/compressed.py?line=1027'>1028</a>     order = self._swap('cf')[0]
# -> <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/scipy/sparse/compressed.py?line=1028'>1029</a> out = self._process_toarray_args(order, out)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/scipy/sparse/compressed.py?line=1029'>1030</a> if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/scipy/sparse/compressed.py?line=1030'>1031</a>     raise ValueError('Output array must be C or F contiguous')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\sparse\base.py:1185, in spmatrix._process_toarray_args(self, order, out)
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/scipy/sparse/base.py?line=1182'>1183</a>     return out
#    <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/scipy/sparse/base.py?line=1183'>1184</a> else:
# -> <a href='file:///c%3A/Users/jongm/AppData/Roaming/Python/Python38/site-packages/scipy/sparse/base.py?line=1184'>1185</a>     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 29.4 GiB for an array with shape (314280, 25075) and data type float32

# %%
best3 = compare_models(sort='Accuracy', n_select=3)
# Out:
# <style type="text/css">
# #T_ddcf1 th {
#   text-align: left;
# }
# #T_ddcf1_row0_col0, #T_ddcf1_row1_col0, #T_ddcf1_row2_col0, #T_ddcf1_row3_col0, #T_ddcf1_row4_col0, #T_ddcf1_row4_col1, #T_ddcf1_row4_col2, #T_ddcf1_row4_col3, #T_ddcf1_row4_col5, #T_ddcf1_row4_col6, #T_ddcf1_row4_col7, #T_ddcf1_row5_col0, #T_ddcf1_row5_col1, #T_ddcf1_row5_col2, #T_ddcf1_row5_col3, #T_ddcf1_row5_col4, #T_ddcf1_row5_col5, #T_ddcf1_row5_col6, #T_ddcf1_row5_col7, #T_ddcf1_row6_col0, #T_ddcf1_row6_col1, #T_ddcf1_row6_col3, #T_ddcf1_row6_col5, #T_ddcf1_row6_col6, #T_ddcf1_row6_col7, #T_ddcf1_row7_col0, #T_ddcf1_row7_col1, #T_ddcf1_row7_col3, #T_ddcf1_row7_col5, #T_ddcf1_row7_col6, #T_ddcf1_row7_col7, #T_ddcf1_row8_col0, #T_ddcf1_row8_col1, #T_ddcf1_row8_col2, #T_ddcf1_row8_col3, #T_ddcf1_row8_col4, #T_ddcf1_row8_col5, #T_ddcf1_row8_col6, #T_ddcf1_row8_col7, #T_ddcf1_row9_col0, #T_ddcf1_row9_col1, #T_ddcf1_row9_col2, #T_ddcf1_row9_col3, #T_ddcf1_row9_col4, #T_ddcf1_row9_col5, #T_ddcf1_row9_col6, #T_ddcf1_row9_col7, #T_ddcf1_row10_col0, #T_ddcf1_row10_col1, #T_ddcf1_row10_col2, #T_ddcf1_row10_col3, #T_ddcf1_row10_col4, #T_ddcf1_row10_col5, #T_ddcf1_row10_col6, #T_ddcf1_row10_col7, #T_ddcf1_row11_col0, #T_ddcf1_row11_col1, #T_ddcf1_row11_col2, #T_ddcf1_row11_col3, #T_ddcf1_row11_col4, #T_ddcf1_row11_col5, #T_ddcf1_row11_col6, #T_ddcf1_row11_col7, #T_ddcf1_row12_col0, #T_ddcf1_row12_col1, #T_ddcf1_row12_col2, #T_ddcf1_row12_col3, #T_ddcf1_row12_col4, #T_ddcf1_row12_col5, #T_ddcf1_row12_col6, #T_ddcf1_row12_col7, #T_ddcf1_row13_col0, #T_ddcf1_row13_col1, #T_ddcf1_row13_col2, #T_ddcf1_row13_col3, #T_ddcf1_row13_col4, #T_ddcf1_row13_col5, #T_ddcf1_row13_col6, #T_ddcf1_row13_col7 {
#   text-align: left;
# }
# #T_ddcf1_row0_col1, #T_ddcf1_row0_col2, #T_ddcf1_row0_col3, #T_ddcf1_row0_col4, #T_ddcf1_row0_col5, #T_ddcf1_row0_col6, #T_ddcf1_row0_col7, #T_ddcf1_row1_col1, #T_ddcf1_row1_col2, #T_ddcf1_row1_col3, #T_ddcf1_row1_col4, #T_ddcf1_row1_col5, #T_ddcf1_row1_col6, #T_ddcf1_row1_col7, #T_ddcf1_row2_col1, #T_ddcf1_row2_col2, #T_ddcf1_row2_col3, #T_ddcf1_row2_col4, #T_ddcf1_row2_col5, #T_ddcf1_row2_col6, #T_ddcf1_row2_col7, #T_ddcf1_row3_col1, #T_ddcf1_row3_col2, #T_ddcf1_row3_col3, #T_ddcf1_row3_col4, #T_ddcf1_row3_col5, #T_ddcf1_row3_col6, #T_ddcf1_row3_col7, #T_ddcf1_row4_col4, #T_ddcf1_row6_col2, #T_ddcf1_row6_col4, #T_ddcf1_row7_col2, #T_ddcf1_row7_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ddcf1_row0_col8, #T_ddcf1_row1_col8, #T_ddcf1_row2_col8, #T_ddcf1_row3_col8, #T_ddcf1_row4_col8, #T_ddcf1_row5_col8, #T_ddcf1_row6_col8, #T_ddcf1_row7_col8, #T_ddcf1_row8_col8, #T_ddcf1_row9_col8, #T_ddcf1_row11_col8, #T_ddcf1_row12_col8, #T_ddcf1_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ddcf1_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ddcf1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddcf1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ddcf1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ddcf1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ddcf1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ddcf1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ddcf1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ddcf1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ddcf1_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ddcf1_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddcf1_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_ddcf1_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_ddcf1_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_ddcf1_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_ddcf1_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_ddcf1_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_ddcf1_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_ddcf1_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_ddcf1_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_ddcf1_row0_col8" class="data row0 col8" >0.1230</td>
#     </tr>
#     <tr>
#       <th id="T_ddcf1_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_ddcf1_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_ddcf1_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_ddcf1_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_ddcf1_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_ddcf1_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_ddcf1_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_ddcf1_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_ddcf1_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_ddcf1_row1_col8" class="data row1 col8" >2.0420</td>
#     </tr>
#     <tr>
#       <th id="T_ddcf1_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_ddcf1_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ddcf1_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_ddcf1_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_ddcf1_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_ddcf1_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_ddcf1_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_ddcf1_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_ddcf1_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_ddcf1_row2_col8" class="data row2 col8" >6.4200</td>
#     </tr>
#     <tr>
#       <th id="T_ddcf1_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_ddcf1_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ddcf1_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_ddcf1_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_ddcf1_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_ddcf1_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_ddcf1_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_ddcf1_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_ddcf1_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_ddcf1_row3_col8" class="data row3 col8" >0.2550</td>
#     </tr>
#     <tr>
#       <th id="T_ddcf1_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_ddcf1_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_ddcf1_row4_col1" class="data row4 col1" >0.9974</td>
#       <td id="T_ddcf1_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_ddcf1_row4_col3" class="data row4 col3" >0.9602</td>
#       <td id="T_ddcf1_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_ddcf1_row4_col5" class="data row4 col5" >0.9796</td>
#       <td id="T_ddcf1_row4_col6" class="data row4 col6" >0.9782</td>
#       <td id="T_ddcf1_row4_col7" class="data row4 col7" >0.9785</td>
#       <td id="T_ddcf1_row4_col8" class="data row4 col8" >0.5300</td>
#     </tr>
#     <tr>
#       <th id="T_ddcf1_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_ddcf1_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ddcf1_row5_col1" class="data row5 col1" >0.9970</td>
#       <td id="T_ddcf1_row5_col2" class="data row5 col2" >0.9799</td>
#       <td id="T_ddcf1_row5_col3" class="data row5 col3" >0.9602</td>
#       <td id="T_ddcf1_row5_col4" class="data row5 col4" >0.9945</td>
#       <td id="T_ddcf1_row5_col5" class="data row5 col5" >0.9770</td>
#       <td id="T_ddcf1_row5_col6" class="data row5 col6" >0.9753</td>
#       <td id="T_ddcf1_row5_col7" class="data row5 col7" >0.9756</td>
